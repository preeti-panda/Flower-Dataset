# %%
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.9 kB 640.0 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.9 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 405.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB 660.6 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.5 MB 469.7 kB/s eta 0:00:25
#    ---------------------------------------- 0.1/11.5 MB 416.7 kB/s eta 0:00:28
#    ---------------------------------------- 0.1/11.5 MB 504.4 kB/s eta 0:00:23
#    ---------------------------------------- 0.1/11.5 MB 491.5 kB/s eta 0:00:24
# ...

# %%
import pandas as pd

# %%
df= pd.read_csv("E:\\downloads\\archive\\IRIS.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
specific_row = df.loc[3]
print(specific_row)
# Out:
# sepal_length            4.6
# sepal_width             3.1
# petal_length            1.5
# petal_width             0.2
# species         Iris-setosa
# Name: 3, dtype: object

# %%
column_name = 'sepal_length' 
print(df[df["sepal_length"] > 5.0])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 15            5.7          4.4           1.5          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [118 rows x 5 columns]

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ------- -------------------------------- 30.7/165.9 kB ? eta -:--:--
#      ----------- ------------------------- 51.2/165.9 kB 890.4 kB/s eta 0:00:01
#      ------------- ----------------------- 61.4/165.9 kB 469.7 kB/s eta 0:00:01
#      ---------------------------- ------- 133.1/165.9 kB 718.6 kB/s eta 0:00:01
#      ------------------------------------ 165.9/165.9 kB 714.1 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.0 MB 4.8 MB/s eta 0:00:02
#     --------------------------------------- 0.1/8.0 MB 1.7 MB/s eta 0:00:05
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df.index, df['sepal_length'])
plt.xlabel('Index')  
plt.ylabel('Values')  
plt.title('Bar Graph for sepal_lenght') 
plt.show()
